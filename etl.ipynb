# %%
import pandas as pd

# %%
import os

# %%
path_dir = 'C:\\Users\\suraj\\Desktop\\youtube\\'
for files in os.listdir(path_dir):
    print(files)
# Out:
# CAvideos.csv
# DEvideos.csv
# FRvideos.csv
# GBvideos.csv
# INvideos.csv
# JPvideos.csv
# KRvideos.csv
# MXvideos.csv
# RUvideos.csv
# USvideos.csv

# %%
trending_df = pd.DataFrame()
for files in os.listdir(path_dir):
    df = pd.read_csv(path_dir+files,encoding='latin-1')
    trending_df = pd.concat([trending_df,df],ignore_index=True)

# %%
trending_df.shape
# Out:
# (375942, 16)

# %%
trending_new = (trending_df.dropna(axis='rows', how='any'))

# %%
trending_new.shape
# Out:
# (356464, 16)

# %%
trending_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356464 entries, 0 to 375941
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                356464 non-null  object
#  1   trending_date           356464 non-null  object
#  2   title                   356464 non-null  object
#  3   channel_title           356464 non-null  object
#  4   category_id             356464 non-null  int64
#  5   publish_time            356464 non-null  object
#  6   tags                    356464 non-null  object
#  7   views                   356464 non-null  int64
#  8   likes                   356464 non-null  int64
#  9   dislikes                356464 non-null  int64
#  10  comment_count           356464 non-null  int64
#  11  thumbnail_link          356464 non-null  object
#  12  comments_disabled       356464 non-null  bool
#  13  ratings_disabled        356464 non-null  bool
# ...

# %%
# !pip install mysql-connector-python

# %%
mydb= mysql.connector.connect(
      host = 'localhost',
      user = 'root',
      password = 'Skk@de22',
      use_pure = True)
print(mydb)

# %%
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("CREATE DATABASE ETL_1")
print("Database is created")
# Out:
# Database is created

# %%
mycursor.execute("USE ETL_1")

# %%
mycursor.execute("CREATE TABLE t2_data(video_id varchar(800),trending_date TEXT(100),title varchar(1000),channel_title varchar(1000),category_id int(100),publish_time TEXT(1000),tags text(65000),views int(50),likes int(50),dislikes int(50),comment_count int(50),thumbnail_link varchar(100),comments_disabled varchar(20),ratings_disabled varchar(20),video_error_or_removed varchar(10),description text(65000) )")
print("Table is created....")
# Out:
# Table is created....

# %%
for i,row in trending_new.iterrows():
            #sql = "INSERT INTO employee.t_data VALUES 
            sql = """INSERT INTO t2_data(video_id,trending_date,title,channel_title,category_id,publish_time,tags,views,likes,dislikes,comment_count,thumbnail_link,comments_disabled,ratings_disabled,video_error_or_removed,description) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
            mycursor.execute(sql, tuple(row))
            print("Record inserted")
            mydb.commit()
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...
